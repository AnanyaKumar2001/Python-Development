# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

matplotlib.interactive(True)
plt.ion()
matplotlib.is_interactive()
# Out:
# True

# %%
fig, ax = plt.subplots()

ax.plot([1, 2, 3, 4], [2, 4, 6, 8])

# %%
fig, ax = plt.subplots()

ax.plot([1, 2, 3, 4], [2, 4, 6, 8])

ax.text(1, 4, "Copy Right", fontsize=32, color='r', ha="left", va="bottom", alpha=0.3)
# Out:
# Text(1, 4, 'Copy Right')

# %%
fig, ax = plt.subplots()

ax.plot([1, 2, 3, 4], [2, 4, 6, 8])

ax.text(1, 4, "Copy Right", fontsize=32, color='r', ha="right", va="top", alpha=0.3)
# Out:
# Text(1, 4, 'Copy Right')

# %%
x = np.linspace(start=0, stop=10, num=50)

# %%
fig = plt.figure(figsize=(8, 8)) 

ax1 = fig.add_subplot(221)
ax1.plot([1, 2, 3, 4], 
         [2, 4, 6, 8])
ax1.set_label('straight line')


ax1.text(1, 4, "Do Not Distribute", fontsize=20, color="red", ha='left', va="bottom", alpha=0.5)
# Out:
# Text(1, 4, 'Do Not Distribute')

# %%
fig = plt.figure(figsize=(8, 8)) 

ax1 = fig.add_subplot(221)
ax1.plot([1, 2, 3, 4], 
         [2, 4, 6, 8])
ax1.set_label('straight line')


ax1.text(1, 4, "Do Not Distribute", fontsize=20, color="red", ha='left', va="bottom", alpha=0.5)

ax2 = fig.add_subplot(222)
ax2.plot(x, np.sin(x))

ax3 = fig.add_subplot(223)
ax3.plot(x, np.cos(x))

# %%
fig = plt.figure(figsize=(8, 8)) 

ax1 = fig.add_subplot(221)
ax1.plot([1, 2, 3, 4], 
         [2, 4, 6, 8])
ax1.set_label('straight line')


ax1.text(1, 4, "Do Not Distribute", fontsize=20, color="red", ha='left', va="bottom", alpha=0.5)

ax2 = fig.add_subplot(222)
ax2.plot(x, np.sin(x))

ax3 = fig.add_subplot(223)
ax3.plot(x, np.cos(x))

fig.text(0.1, 0.5, "Property of Helalee", fontsize=40, color="grey", ha='left', va="bottom", alpha=0.3)
# Out:
# Text(0.1, 0.5, 'Property of Helalee')

# %%
import matplotlib.image as image
import matplotlib.cbook as cbook

# %%
datafile = cbook.get_sample_data("C:\\copy.png", asfileobj=False)

# %%
im = image.imread(datafile)

# %%
fig = plt.figure(figsize=(14, 14)) 

ax1 = fig.add_subplot(221)
ax1.plot([1, 2, 3, 4], 
         [2, 4, 6, 8])
ax1.set_label('straight line')


ax1.text(1, 4, "Do Not Distribute", fontsize=20, color="red", ha='left', va="bottom", alpha=0.5)

ax2 = fig.add_subplot(222)
ax2.plot(x, np.sin(x))

ax3 = fig.add_subplot(223)
ax3.plot(x, np.cos(x))

fig.figimage(im, 100, 150, zorder=3, alpha=0.3)
