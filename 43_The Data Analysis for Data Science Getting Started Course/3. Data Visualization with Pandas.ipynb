# %%
import pandas as pd
import matplotlib as mpl

# %%
df = pd.read_csv('sales.csv')

# %%
df['Quantity'].hist()
# Out:
# <AxesSubplot:>

# %%
df['ProdCategory'].value_counts().plot(kind="barh")
# Out:
# <AxesSubplot:>
