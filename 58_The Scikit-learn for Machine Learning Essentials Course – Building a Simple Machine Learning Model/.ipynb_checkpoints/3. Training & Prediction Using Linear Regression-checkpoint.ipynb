# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
housing_data = pd.read_csv('datasets/housing.csv')
housing_data = housing_data.dropna()
housing_data.shape
# Out:
# (20433, 10)

# %%
housing_data.loc[housing_data['median_house_value'] == 500001].count()
# Out:
# longitude             958
# latitude              958
# housing_median_age    958
# total_rooms           958
# total_bedrooms        958
# population            958
# households            958
# median_income         958
# median_house_value    958
# ocean_proximity       958
# dtype: int64

# %%
housing_data = housing_data.drop(housing_data.loc[housing_data['median_house_value'] == 500001].index)
housing_data.shape
# Out:
# (19475, 10)

# %%
housing_data['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
housing_data = pd.get_dummies(housing_data, columns=['ocean_proximity'])
housing_data.shape
# Out:
# (19475, 14)

# %%
X = housing_data.drop('median_house_value', axis=1)
Y = housing_data['median_house_value']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
x_train.shape, x_test.shape
# Out:
# ((15580, 13), (3895, 13))

# %%
y_train.shape, y_test.shape
# Out:
# ((15580,), (3895,))

# %%
from sklearn.linear_model import LinearRegression

linear_model = LinearRegression(normalize=True, fit_intercept=False).fit(x_train, y_train)

# %%
print("Training Score:", linear_model.score(x_train, y_train))
# Out:
# Training Score: 0.6164391548081923

# %%
predictors = x_train.columns
predictors
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'ocean_proximity_<1H OCEAN', 'ocean_proximity_INLAND',
#        'ocean_proximity_ISLAND', 'ocean_proximity_NEAR BAY',
#        'ocean_proximity_NEAR OCEAN'],
#       dtype='object')

# %%
coef = pd.Series(linear_model.coef_, predictors).sort_values()
print(coef)
# Out:
# ocean_proximity_INLAND       -2.108327e+06
# ocean_proximity_NEAR BAY     -2.076621e+06
# ocean_proximity_<1H OCEAN    -2.070550e+06
# ocean_proximity_NEAR OCEAN   -2.066568e+06
# ocean_proximity_ISLAND       -1.904168e+06
# longitude                    -2.417985e+04
# latitude                     -2.226126e+04
# population                   -2.912190e+01
# total_rooms                  -8.445412e+00
# households                    3.938079e+01
# total_bedrooms                9.745029e+01
# housing_median_age            9.122457e+02
# median_income                 3.921722e+04
# dtype: float64

# %%
y_pred = linear_model.predict(x_test)

df_pred_actual = pd.DataFrame({"predicted": y_pred, "actual": y_test})

df_pred_actual.head(10)
# Out:
#            predicted    actual
# 7288   189013.062856  166300.0
# 17546  169670.267796  289100.0
# 988    249598.776276  313700.0
# 4397   150664.964810  170800.0
# 19768   46561.764927   58200.0
# 14820  147140.093876   92500.0
# 15555  132297.372060  114300.0
# 18463  243031.210206  385700.0
# 20047   51144.715236   53100.0
# 370    211201.143573  135800.0

# %%
from sklearn.metrics import r2_score

print("Testing Score:", r2_score(y_test, y_pred))
# Out:
# Testing Score: 0.5984848095552797

# %%
fig, ax = plt.subplots(figsize=(12, 8))

plt.scatter(y_test, y_pred)

# %%
df_pred_actual_sample = df_pred_actual.sample(100)

df_pred_actual_sample = df_pred_actual_sample.reset_index()

# %%
df_pred_actual_sample.head()
# Out:
#    index      predicted    actual
# 0    991  246644.838529  430600.0
# 1   9840  195961.330504  243800.0
# 2  15069  180230.203052  136400.0
# 3  19129  269649.532412  261800.0
# 4  17803  249246.369840  259700.0

# %%
plt.figure(figsize = (20, 10))

plt.plot(df_pred_actual_sample['predicted'], label='Predicted')
plt.plot(df_pred_actual_sample['actual'], label='Actual')

plt.ylabel('median_house_value')

plt.legend()
