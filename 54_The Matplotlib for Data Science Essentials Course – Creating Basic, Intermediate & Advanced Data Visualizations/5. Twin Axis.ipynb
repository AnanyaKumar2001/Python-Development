# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

matplotlib.interactive(True)
plt.ion()
matplotlib.is_interactive()
# Out:
# True

# %%
austin_weather = pd.read_csv('datasets/austin_weather.csv')
austin_weather.head()
# Out:
#          Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0  2013-12-21         74        60        45            67           49
# 1  2013-12-22         56        48        39            43           36
# 2  2013-12-23         58        45        32            31           27
# 3  2013-12-24         61        46        31            36           28
# 4  2013-12-25         58        50        41            44           40
#
#   DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  ...  \
# 0           43                  93                 75                 57  ...
# 1           28                  93                 68                 43  ...
# 2           23                  76                 52                 27  ...
# 3           21                  89                 56                 22  ...
# 4           36                  86                 71                 56  ...
#
#   SeaLevelPressureAvgInches SeaLevelPressureLowInches VisibilityHighMiles  \
# 0                     29.68                     29.59                  10
# 1                     30.13                     29.87                  10
# 2                     30.49                     30.41                  10
# 3                     30.45                      30.3                  10
# 4                     30.33                     30.27                  10
#
#   VisibilityAvgMiles VisibilityLowMiles WindHighMPH WindAvgMPH WindGustMPH  \
# 0                  7                  2          20          4          31
# 1                 10                  5          16          6          25
# 2                 10                 10           8          3          12
# 3                 10                  7          12          4          20
# 4                 10                  7          10          2          16
#
#   PrecipitationSumInches               Events
# 0                   0.46  Rain , Thunderstorm
# 1                      0
# 2                      0
# 3                      0
# 4                      T
#
# [5 rows x 21 columns]

# %%
austin_weather = austin_weather[['Date', 'TempAvgF', 'WindAvgMPH']].head(30)
austin_weather
# Out:
#           Date  TempAvgF WindAvgMPH
# 0   2013-12-21        60          4
# 1   2013-12-22        48          6
# 2   2013-12-23        45          3
# 3   2013-12-24        46          4
# 4   2013-12-25        50          2
# 5   2013-12-26        48          3
# 6   2013-12-27        53          1
# 7   2013-12-28        51          2
# 8   2013-12-29        50          5
# 9   2013-12-30        40          5
# 10  2013-12-31        46          1
# 11  2014-01-01        54          4
# 12  2014-01-02        44          8
# 13  2014-01-03        43          4
# 14  2014-01-04        57          7
# 15  2014-01-05        47         10
# 16  2014-01-06        29          7
# 17  2014-01-07        35          5
# 18  2014-01-08        47          1
# 19  2014-01-09        62          3
# 20  2014-01-10        65          6
# 21  2014-01-11        62          3
# 22  2014-01-12        57          4
# 23  2014-01-13        57          7
# 24  2014-01-14        57          5
# 25  2014-01-15        52          4
# 26  2014-01-16        56          4
# 27  2014-01-17        54          5
# 28  2014-01-18        54          2
# 29  2014-01-19        59          3

# %%
fig, ax_tempF = plt.subplots()

fig.set_figwidth(12)
fig.set_figheight(6)

# %%
fig, ax_tempF = plt.subplots()

fig.set_figwidth(12)
fig.set_figheight(6)

ax_tempF.set_xlabel("Date")
ax_tempF.tick_params(axis="x", bottom=False, labelbottom=False)

# %%
fig, ax_tempF = plt.subplots()

fig.set_figwidth(12)
fig.set_figheight(6)

ax_tempF.set_xlabel("Date")
ax_tempF.tick_params(axis="x", bottom=False, labelbottom=False)

ax_tempF.set_ylabel("Temperature (F)", color='orange', size='x-large')
ax_tempF.tick_params(axis="y", labelcolor='orange', labelsize='large')

# %%
fig, ax_tempF = plt.subplots()

fig.set_figwidth(12)
fig.set_figheight(6)

ax_tempF.set_xlabel("Date")
ax_tempF.tick_params(axis="x", bottom=False, labelbottom=False)

ax_tempF.set_ylabel("Temperature (F)", color='orange', size='x-large')
ax_tempF.tick_params(axis="y", labelcolor='orange', labelsize='large')

ax_tempF.plot(austin_weather['Date'], austin_weather['TempAvgF'], color="orange")

# %%
fig, ax_tempF = plt.subplots()

fig.set_figwidth(12)
fig.set_figheight(6)

ax_tempF.set_xlabel("Date")
ax_tempF.tick_params(axis="x", bottom=False, labelbottom=False)

ax_tempF.set_ylabel("Temperature (F)", color='orange', size='x-large')
ax_tempF.tick_params(axis="y", labelcolor='orange', labelsize='large')

ax_tempF.plot(austin_weather['Date'], austin_weather['TempAvgF'], color="orange")

ax_wind = ax_tempF.twinx()

# %%
fig, ax_tempF = plt.subplots()

fig.set_figwidth(12)
fig.set_figheight(6)

ax_tempF.set_xlabel("Date")
ax_tempF.tick_params(axis="x", bottom=False, labelbottom=False)

ax_tempF.set_ylabel("Temperature (F)", color='orange', size='x-large')
ax_tempF.tick_params(axis="y", labelcolor='orange', labelsize='large')

ax_tempF.plot(austin_weather['Date'], austin_weather['TempAvgF'], color="orange")

ax_wind = ax_tempF.twinx()

ax_wind.set_ylabel("Average Wind Speed (MPH)", color='green', size='x-large')
ax_wind.tick_params(axis="y", labelcolor='green', labelsize='large')

# %%
fig, ax_tempF = plt.subplots()

fig.set_figwidth(12)
fig.set_figheight(6)

ax_tempF.set_xlabel("Date")
ax_tempF.tick_params(axis="x", bottom=False, labelbottom=False)

ax_tempF.set_ylabel("Temperature (F)", color='orange', size='x-large')
ax_tempF.tick_params(axis="y", labelcolor='orange', labelsize='large')

ax_tempF.plot(austin_weather['Date'], austin_weather['TempAvgF'], color="orange")

ax_wind = ax_tempF.twinx()

ax_wind.set_ylabel("Average Wind Speed (MPH)", color='green', size='x-large')
ax_wind.tick_params(axis="y", labelcolor='green', labelsize='large')

ax_wind.plot(austin_weather['Date'], austin_weather['WindAvgMPH'], color="green")

# %%
def fahrenheit_2_celcius(f):
    return (f - 32) * 5/9

# %%
fig, ax_tempF = plt.subplots()

fig.set_figwidth(12)
fig.set_figheight(6)

# %%
fig, ax_tempF = plt.subplots()

fig.set_figwidth(12)
fig.set_figheight(6)

ax_tempF.set_xlabel("Date")
ax_tempF.tick_params(axis="x", bottom=False, labelbottom=False)

# %%
fig, ax_tempF = plt.subplots()

fig.set_figwidth(12)
fig.set_figheight(6)

ax_tempF.set_xlabel("Date")
ax_tempF.tick_params(axis="x", bottom=False, labelbottom=False)

ax_tempF.set_ylabel("Temperature (F)", color="blue", size="x-large")
ax_tempF.tick_params(axis="y", labelcolor="blue", labelsize="large")

# %%
fig, ax_tempF = plt.subplots()

fig.set_figwidth(12)
fig.set_figheight(6)

ax_tempF.set_xlabel("Date")
ax_tempF.tick_params(axis="x", bottom=False, labelbottom=False)

ax_tempF.set_ylabel("Temperature (F)", color="blue", size="x-large")
ax_tempF.tick_params(axis="y", labelcolor="blue", labelsize="large")

ax_tempF.plot(austin_weather['Date'], austin_weather['TempAvgF'], color="blue")

# %%
fig, ax_tempF = plt.subplots()

fig.set_figwidth(12)
fig.set_figheight(6)

ax_tempF.set_xlabel("Date")
ax_tempF.tick_params(axis="x", bottom=False, labelbottom=False)

ax_tempF.set_ylabel("Temperature (F)", color="blue", size="x-large")
ax_tempF.tick_params(axis="y", labelcolor="blue", labelsize="large")

ax_tempF.plot(austin_weather['Date'], austin_weather['TempAvgF'], color="blue")

ax_tempC = ax_tempF.twinx()

# %%
fig, ax_tempF = plt.subplots()

fig.set_figwidth(12)
fig.set_figheight(6)

ax_tempF.set_xlabel("Date")
ax_tempF.tick_params(axis="x", bottom=False, labelbottom=False)

ax_tempF.set_ylabel("Temperature (F)", color="blue", size="x-large")
ax_tempF.tick_params(axis="y", labelcolor="blue", labelsize="large")

ax_tempF.plot(austin_weather['Date'], austin_weather['TempAvgF'], color="blue")

ax_tempC = ax_tempF.twinx()

ymin, ymax = ax_tempF.get_ylim()

ax_tempC.set_ylim(fahrenheit_2_celcius(ymin), fahrenheit_2_celcius(ymax))

ax_tempC.set_ylabel("Temperature (C)", color="purple", size="x-large")
ax_tempC.tick_params(axis="y", labelcolor="purple", labelsize="large")
