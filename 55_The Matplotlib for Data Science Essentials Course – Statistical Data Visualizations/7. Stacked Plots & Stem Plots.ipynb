# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

matplotlib.interactive(True)
plt.ion()
matplotlib.is_interactive()
# Out:
# True

# %%
np_data= pd.read_csv('datasets/national_parks.csv')
np_data.head()
# Out:
#    Year  Badlands  GrandCanyon  BryceCanyon
# 0  1961    833300      1253000       264800
# 1  1962   1044800      1447400       251000
# 2  1963   1074000      1539500       289500
# 3  1964   1079800      1576600       300300
# 4  1965   1091300      1689200       366800

# %%
x = np_data['Year']

# %%
y = np.vstack([np_data['Badlands'],
               np_data['GrandCanyon'],
               np_data["BryceCanyon"]])

y
# Out:
# array([[ 833300, 1044800, 1074000, 1079800, 1091300, 1094800, 1188700,
#         1194600, 1221300, 1303100, 1282000, 1274600, 1387900, 1205300,
#         1153200, 1210100, 1305400, 1234915,  858000,  952652, 1175952,
#         1030484, 1026981, 1113675,  950242, 1025630, 1174398, 1110040,
#         1237956, 1326475, 1518396, 1205297, 1179458, 1130459, 1075569,
#         1024705,  970696, 1021049,  950453, 1105824,  955469,  908898,
#          871034,  936030,  909146,  840118,  886654,  845734,  933918,
#          977778,  870741,  883406,  892372,  868094,  989354,  996263,
#         1054325],
#        [1253000, 1447400, 1539500, 1576600, 1689200, 1806000, 1804900,
#         1986300, 2192600, 2258200, 2402100, 2698300, 1909700, 1888600,
#         2625100, 2791600, 2627200, 2748642, 2131716, 2304973, 2472270,
#         2293127, 2248082, 2173584, 2711529, 3035787, 3513030, 3859886,
#         3966209, 3776685, 3886031, 4203545, 4575602, 4364316, 4557645,
#         4537703, 4791668, 4239682, 4575124, 4460228, 4104809, 4001974,
#         4124900, 4326234, 4401522, 4279439, 4413668, 4425314, 4348068,
#         4388386, 4298178, 4421352, 4564840, 4756771, 5520736, 5969811,
#         6254238],
#        [ 264800,  251000,  289500,  300300,  366800,  396600,  295000,
#          320800,  366900,  345900,  377800,  424830,  429700,  408800,
#          579200,  625600,  611500,  679260,  558095,  571541,  474092,
#          471517,  472633,  495104,  500782,  578018,  718342,  791348,
#          808045,  862659,  929067, 1018174, 1107951, 1028134,  994548,
#         1269600, 1174824, 1166331, 1081521, 1099275, 1068619,  886436,
#          903760,  987253, 1017681,  890676, 1012563, 1043321, 1216377,
#         1285492, 1296000, 1385352, 1311875, 1435741, 1745804, 2365110,
#         2571684]], dtype=int64)

# %%
labels = ['Badlands', 'GrandCanyon', 'BryceCanyon']

# %%
# *-*-*-*-*-*-*-*-*-*-*-*-*-* Stacked Plots ---------------------------------------------

plt.stackplot(x, y, labels=labels)

plt.legend(loc="upper left")

# %%
colors = ["lawngreen", 'orange', "teal"]

# %%
plt.stackplot(x, y, labels=labels, colors=colors, edgecolor="black")

plt.legend(loc="upper left")

# %%
# *-*-*-*-*-*-*-*-*-*-*-*-*-* Stem Plots ---------------------------------------------

np_data[["Badlands", "GrandCanyon", "BryceCanyon"]] = np_data[["Badlands", "GrandCanyon", "BryceCanyon"]].diff()

np_data
# Out:
#     Year  Badlands  GrandCanyon  BryceCanyon
# 0   1961       NaN          NaN          NaN
# 1   1962  211500.0     194400.0     -13800.0
# 2   1963   29200.0      92100.0      38500.0
# 3   1964    5800.0      37100.0      10800.0
# 4   1965   11500.0     112600.0      66500.0
# 5   1966    3500.0     116800.0      29800.0
# 6   1967   93900.0      -1100.0    -101600.0
# 7   1968    5900.0     181400.0      25800.0
# 8   1969   26700.0     206300.0      46100.0
# 9   1970   81800.0      65600.0     -21000.0
# 10  1971  -21100.0     143900.0      31900.0
# 11  1972   -7400.0     296200.0      47030.0
# 12  1973  113300.0    -788600.0       4870.0
# 13  1974 -182600.0     -21100.0     -20900.0
# 14  1975  -52100.0     736500.0     170400.0
# 15  1976   56900.0     166500.0      46400.0
# 16  1977   95300.0    -164400.0     -14100.0
# 17  1978  -70485.0     121442.0      67760.0
# 18  1979 -376915.0    -616926.0    -121165.0
# 19  1980   94652.0     173257.0      13446.0
# 20  1981  223300.0     167297.0     -97449.0
# 21  1982 -145468.0    -179143.0      -2575.0
# 22  1983   -3503.0     -45045.0       1116.0
# 23  1984   86694.0     -74498.0      22471.0
# 24  1985 -163433.0     537945.0       5678.0
# 25  1986   75388.0     324258.0      77236.0
# 26  1987  148768.0     477243.0     140324.0
# 27  1988  -64358.0     346856.0      73006.0
# 28  1989  127916.0     106323.0      16697.0
# 29  1990   88519.0    -189524.0      54614.0
# 30  1991  191921.0     109346.0      66408.0
# 31  1992 -313099.0     317514.0      89107.0
# 32  1993  -25839.0     372057.0      89777.0
# 33  1994  -48999.0    -211286.0     -79817.0
# 34  1995  -54890.0     193329.0     -33586.0
# 35  1996  -50864.0     -19942.0     275052.0
# 36  1997  -54009.0     253965.0     -94776.0
# 37  1998   50353.0    -551986.0      -8493.0
# 38  1999  -70596.0     335442.0     -84810.0
# 39  2000  155371.0    -114896.0      17754.0
# 40  2001 -150355.0    -355419.0     -30656.0
# 41  2002  -46571.0    -102835.0    -182183.0
# 42  2003  -37864.0     122926.0      17324.0
# 43  2004   64996.0     201334.0      83493.0
# 44  2005  -26884.0      75288.0      30428.0
# 45  2006  -69028.0    -122083.0    -127005.0
# 46  2007   46536.0     134229.0     121887.0
# 47  2008  -40920.0      11646.0      30758.0
# 48  2009   88184.0     -77246.0     173056.0
# 49  2010   43860.0      40318.0      69115.0
# 50  2011 -107037.0     -90208.0      10508.0
# 51  2012   12665.0     123174.0      89352.0
# 52  2013    8966.0     143488.0     -73477.0
# 53  2014  -24278.0     191931.0     123866.0
# 54  2015  121260.0     763965.0     310063.0
# 55  2016    6909.0     449075.0     619306.0
# 56  2017   58062.0     284427.0     206574.0

# %%
plt.figure(figsize=(10, 6))

plt.stem(np_data["Year"], np_data['Badlands'])

plt.title("Change in Number of Visitors")
# Out:
# Text(0.5, 1.0, 'Change in Number of Visitors')

# %%
plt.figure(figsize=(10, 6))

plt.stem(np_data["Year"],
         np_data['Badlands'],
         markerfmt="r_",
         linefmt="g--",
        basefmt=':')

plt.title("Change in Number of Visitors")
# Out:
# Text(0.5, 1.0, 'Change in Number of Visitors')
